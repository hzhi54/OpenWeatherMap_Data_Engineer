# %%
import pymongo
import pandas as pd
import time

# %%
ZIP = ["36104","99801","85001","72201","95814","80202"
    ,"06103","19901","32301","30303","96813","83702"
    ,"62701","46225","50309","66603","40601","70802"
    ,"04330","21401","02201","48933","55102","39205"
    ,"59623","68502","89701","03301","08608","87501"
    ,"12207","27601","58501","43215","73102","97301"
    ,"17101","02903","29217","65101","57501","37219"
    ,"78701","84111","05602","23219","98507","25301"
    ,"53703","82001"]

client = pymongo.MongoClient()
database = client['test']
collection = database['weather']

# %%
cursor = collection.find({},{'_id':0,'main':1,'wind':1,'name':1,'coord':1})
entity = list(cursor)

# %%
entity
# Out:
# [{'coord': {'lon': -86.3081, 'lat': 32.373},
#   'main': {'temp': 83.79,
#    'feels_like': 85.95,
#    'temp_min': 82.04,
#    'temp_max': 85.89,
#    'pressure': 1012,
#    'humidity': 55},
#   'wind': {'speed': 4.61, 'deg': 40},
#   'name': 'Montgomery'},
#  {'coord': {'lon': -134.5294, 'lat': 58.3628},
#   'main': {'temp': 44.83,
#    'feels_like': 44.83,
#    'temp_min': 44.02,
#    'temp_max': 45.82,
#    'pressure': 1014,
#    'humidity': 93},
#   'wind': {'speed': 0, 'deg': 0},
#   'name': 'Juneau'},
#  {'coord': {'lon': -112.074, 'lat': 33.4484},
#   'main': {'temp': 82.85,
#    'feels_like': 80.46,
#    'temp_min': 79.14,
#    'temp_max': 85.62,
#    'pressure': 1011,
#    'humidity': 20},
#   'wind': {'speed': 1.99, 'deg': 297, 'gust': 4},
#   'name': 'Phoenix'},
#  {'coord': {'lon': -92.2819, 'lat': 34.7483},
#   'main': {'temp': 85.12,
#    'feels_like': 86.63,
#    'temp_min': 83.8,
#    'temp_max': 87.48,
#    'pressure': 1008,
#    'humidity': 50},
#   'wind': {'speed': 14.97, 'deg': 200, 'gust': 24.16},
#   'name': 'Little Rock'},
#  {'coord': {'lon': -121.4922, 'lat': 38.5804},
#   'main': {'temp': 76.12,
#    'feels_like': 74.98,
#    'temp_min': 72.91,
#    'temp_max': 82.17,
#    'pressure': 1018,
#    'humidity': 33},
#   'wind': {'speed': 3.44, 'deg': 0},
#   'name': 'Sacramento'},
#  {'coord': {'lon': -104.9946, 'lat': 39.7491},
#   'main': {'temp': 66.15,
#    'feels_like': 63.77,
#    'temp_min': 58.77,
#    'temp_max': 71.92,
#    'pressure': 1005,
#    'humidity': 28},
#   'wind': {'speed': 3, 'deg': 78, 'gust': 8.01},
#   'name': 'Denver'},
#  {'coord': {'lon': -72.676, 'lat': 41.7672},
#   'main': {'temp': 63.34,
#    'feels_like': 63.18,
#    'temp_min': 60.75,
#    'temp_max': 65.01,
#    'pressure': 1021,
#    'humidity': 81},
#   'wind': {'speed': 6.91, 'deg': 60},
#   'name': 'Hartford'},
#  {'coord': {'lon': -75.4955, 'lat': 39.1564},
#   'main': {'temp': 68,
#    'feels_like': 69.1,
#    'temp_min': 65.14,
#    'temp_max': 70.02,
#    'pressure': 1016,
#    'humidity': 98},
#   'wind': {'speed': 13.8, 'deg': 20},
#   'name': 'Dover'},
#  {'coord': {'lon': -84.2593, 'lat': 30.4286},
#   'main': {'temp': 82.08,
#    'feels_like': 85.32,
#    'temp_min': 79.25,
#    'temp_max': 84.13,
#    'pressure': 1013,
#    'humidity': 64},
#   'wind': {'speed': 1.01, 'deg': 135, 'gust': 1.99},
#   'name': 'Tallahassee'},
#  {'coord': {'lon': -84.3888, 'lat': 33.7525},
#   'main': {'temp': 79.09,
#    'feels_like': 79.09,
#    'temp_min': 75.2,
#    'temp_max': 82.92,
#    'pressure': 1015,
#    'humidity': 63},
#   'wind': {'speed': 4.61, 'deg': 120},
#   'name': 'Atlanta'},
#  {'coord': {'lon': -157.8521, 'lat': 21.3179},
#   'main': {'temp': 81.97,
#    'feels_like': 84.56,
#    'temp_min': 78.01,
#    'temp_max': 87.58,
#    'pressure': 1017,
#    'humidity': 61},
#   'wind': {'speed': 3, 'deg': 123, 'gust': 18.99},
#   'name': 'Honolulu'},
#  {'coord': {'lon': -116.2052, 'lat': 43.6322},
#   'main': {'temp': 62.71,
#    'feels_like': 60.66,
#    'temp_min': 59.11,
#    'temp_max': 68.32,
#    'pressure': 1016,
#    'humidity': 42},
#   'wind': {'speed': 1.01, 'deg': 72, 'gust': 5.01},
#   'name': 'Boise'},
#  {'coord': {'lon': -89.6495, 'lat': 39.8},
#   'main': {'temp': 85.82,
#    'feels_like': 86.34,
#    'temp_min': 83.53,
#    'temp_max': 88.11,
#    'pressure': 1005,
#    'humidity': 45},
#   'wind': {'speed': 4, 'deg': 158, 'gust': 8.99},
#   'name': 'Springfield'},
#  {'coord': {'lon': -86.1569, 'lat': 39.7406},
#   'main': {'temp': 82.09,
#    'feels_like': 84.38,
#    'temp_min': 79.47,
#    'temp_max': 84.58,
#    'pressure': 1011,
#    'humidity': 59},
#   'wind': {'speed': 18.41, 'deg': 180},
#   'name': 'Indianapolis'},
#  {'coord': {'lon': -93.6212, 'lat': 41.5887},
#   'main': {'temp': 71.01,
#    'feels_like': 70.57,
#    'temp_min': 68.45,
#    'temp_max': 72.55,
#    'pressure': 1003,
#    'humidity': 59},
#   'wind': {'speed': 5.01, 'deg': 219, 'gust': 11.99},
#   'name': 'Des Moines'},
#  {'coord': {'lon': -95.6802, 'lat': 39.0553},
#   'main': {'temp': 75.58,
#    'feels_like': 75.27,
#    'temp_min': 72.63,
#    'temp_max': 79.18,
#    'pressure': 1005,
#    'humidity': 52},
#   'wind': {'speed': 4, 'deg': 1, 'gust': 10},
#   'name': 'Topeka'},
#  {'coord': {'lon': -84.8697, 'lat': 38.2281},
#   'main': {'temp': 82.26,
#    'feels_like': 84.06,
#    'temp_min': 79.45,
#    'temp_max': 85.19,
#    'pressure': 1013,
#    'humidity': 56},
#   'wind': {'speed': 7, 'deg': 185, 'gust': 11.01},
#   'name': 'Frankfort'},
#  {'coord': {'lon': -91.1775, 'lat': 30.4438},
#   'main': {'temp': 87.01,
#    'feels_like': 93.49,
#    'temp_min': 82.85,
#    'temp_max': 89.91,
#    'pressure': 1011,
#    'humidity': 61},
#   'wind': {'speed': 4, 'deg': 180, 'gust': 11.99},
#   'name': 'Baton Rouge'},
#  {'coord': {'lon': -69.7665, 'lat': 44.3232},
#   'main': {'temp': 59.85,
#    'feels_like': 59.61,
#    'temp_min': 57.76,
#    'temp_max': 61.66,
#    'pressure': 1024,
#    'humidity': 87},
#   'wind': {'speed': 1.01, 'deg': 0, 'gust': 8.99},
#   'name': 'Augusta'},
#  {'coord': {'lon': -76.5501, 'lat': 38.9898},
#   'main': {'temp': 69.42,
#    'feels_like': 70.05,
#    'temp_min': 66.31,
#    'temp_max': 73.2,
#    'pressure': 1017,
#    'humidity': 85},
#   'wind': {'speed': 7, 'deg': 80, 'gust': 14},
#   'name': 'Annapolis'},
#  {'coord': {'lon': -71.0598, 'lat': 42.3584},
#   'main': {'temp': 61.86,
#    'feels_like': 61.61,
#    'temp_min': 59.83,
#    'temp_max': 63.59,
#    'pressure': 1024,
#    'humidity': 82},
#   'wind': {'speed': 5.01, 'deg': 168, 'gust': 13},
#   'name': 'Boston'},
#  {'coord': {'lon': -84.5571, 'lat': 42.7334},
#   'main': {'temp': 76.39,
#    'feels_like': 77.4,
#    'temp_min': 72.9,
#    'temp_max': 80.53,
#    'pressure': 1009,
#    'humidity': 78},
#   'wind': {'speed': 12.66, 'deg': 180},
#   'name': 'Lansing'},
#  {'coord': {'lon': -93.1209, 'lat': 44.9372},
#   'main': {'temp': 67.55,
#    'feels_like': 66.87,
#    'temp_min': 62.08,
#    'temp_max': 72.75,
#    'pressure': 999,
#    'humidity': 61},
#   'wind': {'speed': 3, 'deg': 173, 'gust': 11.01},
#   'name': 'Saint Paul'},
#  {'coord': {'lon': -90.1848, 'lat': 32.2988},
#   'main': {'temp': 87.21,
#    'feels_like': 89.74,
#    'temp_min': 85.17,
#    'temp_max': 87.93,
#    'pressure': 1012,
#    'humidity': 50},
#   'wind': {'speed': 12.66, 'deg': 180},
#   'name': 'Jackson'},
#  {'coord': {'lon': -112.0402, 'lat': 46.5901},
#   'main': {'temp': 61.45,
#    'feels_like': 58.84,
#    'temp_min': 58.24,
#    'temp_max': 63.5,
#    'pressure': 1009,
#    'humidity': 33},
#   'wind': {'speed': 11.99, 'deg': 268, 'gust': 21},
#   'name': 'Helena'},
#  {'coord': {'lon': -96.6938, 'lat': 40.7893},
#   'main': {'temp': 66,
#    'feels_like': 65.03,
#    'temp_min': 62.74,
#    'temp_max': 69.4,
#    'pressure': 1005,
#    'humidity': 58},
#   'wind': {'speed': 1.01, 'deg': 359, 'gust': 1.99},
#   'name': 'Lincoln'},
#  {'coord': {'lon': -119.7459, 'lat': 39.1507},
#   'main': {'temp': 64.36,
#    'feels_like': 61.21,
#    'temp_min': 52.41,
#    'temp_max': 70.95,
#    'pressure': 1020,
#    'humidity': 15},
#   'wind': {'speed': 3.44, 'deg': 0},
#   'name': 'Carson City'},
#  {'coord': {'lon': -71.5277, 'lat': 43.2185},
#   'main': {'temp': 61.25,
#    'feels_like': 60.98,
#    'temp_min': 59.22,
#    'temp_max': 63.91,
#    'pressure': 1019,
#    'humidity': 83},
#   'wind': {'speed': 4.61, 'deg': 130},
#   'name': 'Concord'},
#  {'coord': {'lon': -74.7622, 'lat': 40.2204},
#   'main': {'temp': 64.92,
#    'feels_like': 65.59,
#    'temp_min': 61.2,
#    'temp_max': 68.13,
#    'pressure': 1016,
#    'humidity': 95},
#   'wind': {'speed': 5.99, 'deg': 28, 'gust': 11.01},
#   'name': 'Trenton'},
#  {'coord': {'lon': -105.9821, 'lat': 35.6975},
#   'main': {'temp': 56.68,
#    'feels_like': 53.87,
#    'temp_min': 48.22,
#    'temp_max': 63.52,
#    'pressure': 1014,
#    'humidity': 39},
#   'wind': {'speed': 3, 'deg': 323, 'gust': 11.01},
#   'name': 'Santa Fe'},
#  {'coord': {'lon': -73.7562, 'lat': 42.6526},
#   'main': {'temp': 65.21,
#    'feels_like': 65.1,
#    'temp_min': 61.88,
#    'temp_max': 68.41,
#    'pressure': 1022,
#    'humidity': 78},
#   'wind': {'speed': 4.61, 'deg': 110},
#   'name': 'Albany'},
#  {'coord': {'lon': -78.6324, 'lat': 35.7727},
#   'main': {'temp': 73.92,
#    'feels_like': 74.88,
#    'temp_min': 71.08,
#    'temp_max': 76.14,
#    'pressure': 1013,
#    'humidity': 82},
#   'wind': {'speed': 3, 'deg': 67, 'gust': 7},
#   'name': 'Raleigh'},
#  {'coord': {'lon': -100.7837, 'lat': 46.8083},
#   'main': {'temp': 65.75,
#    'feels_like': 64.09,
#    'temp_min': 64.81,
#    'temp_max': 68.86,
#    'pressure': 1003,
#    'humidity': 44},
#   'wind': {'speed': 14.97, 'deg': 290, 'gust': 24.16},
#   'name': 'Bismarck'},
#  {'coord': {'lon': -83.0044, 'lat': 39.9671},
#   'main': {'temp': 81.21,
#    'feels_like': 83.5,
#    'temp_min': 78.33,
#    'temp_max': 83.68,
#    'pressure': 1013,
#    'humidity': 61},
#   'wind': {'speed': 1.01, 'deg': 271, 'gust': 3},
#   'name': 'Columbus'},
#  {'coord': {'lon': -97.5199, 'lat': 35.4726},
#   'main': {'temp': 82.42,
#    'feels_like': 83.73,
#    'temp_min': 80.1,
#    'temp_max': 83.97,
#    'pressure': 1003,
#    'humidity': 53},
#   'wind': {'speed': 13.8, 'deg': 180},
#   'name': 'Oklahoma City'},
#  {'coord': {'lon': -123.004, 'lat': 44.949},
#   'main': {'temp': 56.21,
#    'feels_like': 54.63,
#    'temp_min': 52.05,
#    'temp_max': 59.09,
#    'pressure': 1026,
#    'humidity': 66},
#   'wind': {'speed': 10.36, 'deg': 290},
#   'name': 'Salem'},
#  {'coord': {'lon': -76.8831, 'lat': 40.2618},
#   'main': {'temp': 65.5,
#    'feels_like': 65.55,
#    'temp_min': 63.25,
#    'temp_max': 67.37,
#    'pressure': 1018,
#    'humidity': 81},
#   'wind': {'speed': 8.01, 'deg': 110, 'gust': 11.01},
#   'name': 'Harrisburg'},
#  {'coord': {'lon': -71.4158, 'lat': 41.82},
#   'main': {'temp': 61.23,
#    'feels_like': 61.23,
#    'temp_min': 59.58,
#    'temp_max': 63.41,
#    'pressure': 1020,
#    'humidity': 89},
#   'wind': {'speed': 11.5, 'deg': 50},
#   'name': 'Providence'},
#  {'coord': {'lon': -81.0348, 'lat': 34.0007},
#   'main': {'temp': 80.51,
#    'feels_like': 82.31,
#    'temp_min': 77.41,
#    'temp_max': 82.56,
#    'pressure': 1014,
#    'humidity': 59},
#   'wind': {'speed': 1.99, 'deg': 337, 'gust': 7},
#   'name': 'Columbia'},
#  {'coord': {'lon': -92.1525, 'lat': 38.5462},
#   'main': {'temp': 82.98,
#    'feels_like': 83.52,
#    'temp_min': 81.34,
#    'temp_max': 85.71,
#    'pressure': 1005,
#    'humidity': 48},
#   'wind': {'speed': 5.75, 'deg': 0},
#   'name': 'Jefferson City'},
#  {'coord': {'lon': -100.3211, 'lat': 44.3695},
#   'main': {'temp': 67.84,
#    'feels_like': 66.87,
#    'temp_min': 67.24,
#    'temp_max': 69.91,
#    'pressure': 1004,
#    'humidity': 54},
#   'wind': {'speed': 8.01, 'deg': 243, 'gust': 13},
#   'name': 'Pierre'},
#  {'coord': {'lon': -86.7837, 'lat': 36.1678},
#   'main': {'temp': 83.89,
#    'feels_like': 85.42,
#    'temp_min': 81.64,
#    'temp_max': 85.95,
#    'pressure': 1005,
#    'humidity': 52},
#   'wind': {'speed': 5.99, 'deg': 161, 'gust': 13},
#   'name': 'Nashville'},
#  {'coord': {'lon': -97.7426, 'lat': 30.2713},
#   'main': {'temp': 90.34,
#    'feels_like': 101.08,
#    'temp_min': 87.82,
#    'temp_max': 93.2,
#    'pressure': 1004,
#    'humidity': 61},
#   'wind': {'speed': 4, 'deg': 139, 'gust': 14},
#   'name': 'Austin'},
#  {'coord': {'lon': -111.881, 'lat': 40.7548},
#   'main': {'temp': 59.07,
#    'feels_like': 56.84,
#    'temp_min': 54.99,
#    'temp_max': 63.14,
#    'pressure': 1019,
#    'humidity': 46},
#   'wind': {'speed': 4, 'deg': 262, 'gust': 11.01},
#   'name': 'Salt Lake City'},
#  {'coord': {'lon': -72.577, 'lat': 44.2641},
#   'main': {'temp': 63.03,
#    'feels_like': 62.1,
#    'temp_min': 59.54,
#    'temp_max': 66.58,
#    'pressure': 1023,
#    'humidity': 65},
#   'wind': {'speed': 3, 'deg': 209, 'gust': 7},
#   'name': 'Montpelier'},
#  {'coord': {'lon': -77.4378, 'lat': 37.5463},
#   'main': {'temp': 74.41,
#    'feels_like': 75.4,
#    'temp_min': 72,
#    'temp_max': 76.17,
#    'pressure': 1016,
#    'humidity': 82},
#   'wind': {'speed': 5.99, 'deg': 23, 'gust': 18.01},
#   'name': 'Richmond'},
#  {'coord': {'lon': -122.9007, 'lat': 47.0379},
#   'main': {'temp': 56.7,
#    'feels_like': 54.93,
#    'temp_min': 51.4,
#    'temp_max': 60.66,
#    'pressure': 1021,
#    'humidity': 61},
#   'wind': {'speed': 7, 'deg': 288, 'gust': 20},
#   'name': 'Olympia'},
#  {'coord': {'lon': -81.6306, 'lat': 38.349},
#   'main': {'temp': 80.35,
#    'feels_like': 81.88,
#    'temp_min': 78.33,
#    'temp_max': 83.41,
#    'pressure': 1014,
#    'humidity': 57},
#   'wind': {'speed': 0, 'deg': 0},
#   'name': 'Charleston'},
#  {'coord': {'lon': -89.3831, 'lat': 43.0775},
#   'main': {'temp': 70.48,
#    'feels_like': 70.81,
#    'temp_min': 68.95,
#    'temp_max': 72.79,
#    'pressure': 1004,
#    'humidity': 76},
#   'wind': {'speed': 14.97, 'deg': 190},
#   'name': 'Madison'},
#  {'coord': {'lon': -104.7962, 'lat': 41.1437},
#   'main': {'temp': 61.18,
#    'feels_like': 58.35,
#    'temp_min': 58.91,
#    'temp_max': 63.91,
#    'pressure': 1012,
#    'humidity': 29},
#   'wind': {'speed': 20.71, 'deg': 280, 'gust': 32.21},
#   'name': 'Cheyenne'}]

# %%
weather_dict = {'Name':[],'Temperature':[],'Temp_Min':[],'Temp_Max':[],'Humidity':[],'Wind':[],'Zip':[],'Latitude':[],'Longitude':[]}
for i,ent in enumerate(entity):
    weather_dict['Name'].append(ent['name'])
    weather_dict['Temperature'].append(ent['main']['temp'])
    weather_dict['Temp_Min'].append(ent['main']['temp_min'])
    weather_dict['Temp_Max'].append(ent['main']['temp_max'])
    weather_dict['Humidity'].append(ent['main']['humidity'])
    weather_dict['Wind'].append(ent['wind']['speed'])
    weather_dict['Zip'].append(ZIP[i])
    weather_dict['Latitude'].append(ent['coord']['lat'])
    weather_dict['Longitude'].append(ent['coord']['lon'])
    
df = pd.DataFrame(weather_dict)
df
# Out:
#               Name  Temperature  Temp_Min  Temp_Max  Humidity   Wind    Zip
# 0       Montgomery        83.79     82.04     85.89        55   4.61  36104
# 1           Juneau        44.83     44.02     45.82        93   0.00  99801
# 2          Phoenix        82.85     79.14     85.62        20   1.99  85001
# 3      Little Rock        85.12     83.80     87.48        50  14.97  72201
# 4       Sacramento        76.12     72.91     82.17        33   3.44  95814
# 5           Denver        66.15     58.77     71.92        28   3.00  80202
# 6         Hartford        63.34     60.75     65.01        81   6.91  06103
# 7            Dover        68.00     65.14     70.02        98  13.80  19901
# 8      Tallahassee        82.08     79.25     84.13        64   1.01  32301
# 9          Atlanta        79.09     75.20     82.92        63   4.61  30303
# 10        Honolulu        81.97     78.01     87.58        61   3.00  96813
# 11           Boise        62.71     59.11     68.32        42   1.01  83702
# 12     Springfield        85.82     83.53     88.11        45   4.00  62701
# 13    Indianapolis        82.09     79.47     84.58        59  18.41  46225
# 14      Des Moines        71.01     68.45     72.55        59   5.01  50309
# 15          Topeka        75.58     72.63     79.18        52   4.00  66603
# 16       Frankfort        82.26     79.45     85.19        56   7.00  40601
# 17     Baton Rouge        87.01     82.85     89.91        61   4.00  70802
# 18         Augusta        59.85     57.76     61.66        87   1.01  04330
# 19       Annapolis        69.42     66.31     73.20        85   7.00  21401
# 20          Boston        61.86     59.83     63.59        82   5.01  02201
# 21         Lansing        76.39     72.90     80.53        78  12.66  48933
# 22      Saint Paul        67.55     62.08     72.75        61   3.00  55102
# 23         Jackson        87.21     85.17     87.93        50  12.66  39205
# 24          Helena        61.45     58.24     63.50        33  11.99  59623
# 25         Lincoln        66.00     62.74     69.40        58   1.01  68502
# 26     Carson City        64.36     52.41     70.95        15   3.44  89701
# 27         Concord        61.25     59.22     63.91        83   4.61  03301
# 28         Trenton        64.92     61.20     68.13        95   5.99  08608
# 29        Santa Fe        56.68     48.22     63.52        39   3.00  87501
# 30          Albany        65.21     61.88     68.41        78   4.61  12207
# 31         Raleigh        73.92     71.08     76.14        82   3.00  27601
# 32        Bismarck        65.75     64.81     68.86        44  14.97  58501
# 33        Columbus        81.21     78.33     83.68        61   1.01  43215
# 34   Oklahoma City        82.42     80.10     83.97        53  13.80  73102
# 35           Salem        56.21     52.05     59.09        66  10.36  97301
# 36      Harrisburg        65.50     63.25     67.37        81   8.01  17101
# 37      Providence        61.23     59.58     63.41        89  11.50  02903
# 38        Columbia        80.51     77.41     82.56        59   1.99  29217
# 39  Jefferson City        82.98     81.34     85.71        48   5.75  65101
# 40          Pierre        67.84     67.24     69.91        54   8.01  57501
# 41       Nashville        83.89     81.64     85.95        52   5.99  37219
# 42          Austin        90.34     87.82     93.20        61   4.00  78701
# 43  Salt Lake City        59.07     54.99     63.14        46   4.00  84111
# 44      Montpelier        63.03     59.54     66.58        65   3.00  05602
# 45        Richmond        74.41     72.00     76.17        82   5.99  23219
# 46         Olympia        56.70     51.40     60.66        61   7.00  98507
# 47      Charleston        80.35     78.33     83.41        57   0.00  25301
# 48         Madison        70.48     68.95     72.79        76  14.97  53703
# 49        Cheyenne        61.18     58.91     63.91        29  20.71  82001

# %%
df[df['Name'] == "Montgomery" ].Zip[0]
# Out:
# '36104'

# %%
client = pymongo.MongoClient()
database = client['test']
collection = database['forecast']

# %%
cursor = collection.find({},{'_id':0,'daily':1})
entity = list(cursor)

# %%
forecast_dict = {'dt':[],'Temperature':[],'Temp_Min':[],'Temp_Max':[],'Humidity':[],'Wind':[],'Main':[],'Zip':[]}
for i,ent in enumerate(entity):
    daily = ent['daily']
    for j in range(len(daily)):
        forecast_dict['dt'].append(daily[j]['dt'])
        forecast_dict['Temperature'].append(daily[j]['temp']['day'])
        forecast_dict['Temp_Min'].append(daily[j]['temp']['min'])
        forecast_dict['Temp_Max'].append(daily[j]['temp']['max'])
        forecast_dict['Humidity'].append(daily[j]['humidity'])
        forecast_dict['Wind'].append(daily[j]['wind_speed'])
        forecast_dict['Main'].append(daily[j]['weather'][0]['main'])
        forecast_dict['Zip'].append(ZIP[i])
    
df = pd.DataFrame(forecast_dict)
df.head(5)
# Out:
#            dt  Temperature  Temp_Min  Temp_Max  Humidity  Wind    Main    Zip
# 0  1633885200        81.07     64.15     83.71        58  6.85  Clouds  36104
# 1  1633971600        80.19     63.63     83.19        55  6.46  Clouds  36104
# 2  1634058000        82.78     65.79     86.02        55  5.75   Clear  36104
# 3  1634144400        84.15     66.69     84.20        46  7.18  Clouds  36104
# 4  1634230800        85.05     65.86     85.05        51  5.32  Clouds  36104

# %%
client = pymongo.MongoClient()
database = client['test']
collection = database['history']

# %%
cursor = collection.find({},{'_id':0,'lat':1 , 'lon': 1, 'current':1})
entity = list(cursor)

# %%
entity[0]
# Out:
# {'lat': 32.3777,
#  'lon': -86.3006,
#  'current': {'dt': 1633469753,
#   'sunrise': 1633434115,
#   'sunset': 1633476293,
#   'temp': 74.14,
#   'feels_like': 75.25,
#   'pressure': 1012,
#   'humidity': 85,
#   'dew_point': 69.33,
#   'uvi': 0.77,
#   'clouds': 75,
#   'visibility': 10000,
#   'wind_speed': 1.01,
#   'wind_deg': 49,
#   'wind_gust': 1.99,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'rain': {'1h': 1.15}}}

# %%
history_dict = {'dt':[],'Temperature':[],'Humidity':[],'Wind':[],'Main':[],'Lat':[],'Lon':[]}
for i,ent in enumerate(entity):
    daily = ent['current']
    history_dict['dt'].append(daily['dt'])
    history_dict['Temperature'].append(daily['temp'])
    history_dict['Humidity'].append(daily['humidity'])
    history_dict['Wind'].append(daily['wind_speed'])
    history_dict['Main'].append(daily['weather'][0]['main'])
    history_dict['Lat'].append(ent['lat'])
    history_dict['Lon'].append(ent['lon'])

df = pd.DataFrame(forecast_dict)
df.head(5)
# Out:
#            dt  Temperature  Temp_Min  Temp_Max  Humidity  Wind    Main    Zip
# 0  1633885200        81.07     64.15     83.71        58  6.85  Clouds  36104
# 1  1633971600        80.19     63.63     83.19        55  6.46  Clouds  36104
# 2  1634058000        82.78     65.79     86.02        55  5.75   Clear  36104
# 3  1634144400        84.15     66.69     84.20        46  7.18  Clouds  36104
# 4  1634230800        85.05     65.86     85.05        51  5.32  Clouds  36104
